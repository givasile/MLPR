# %%
from sklearn import linear_model
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
import sklearn.model_selection as model_selection
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# arguments
test_size = .2
random_state = 21

# load and split
diabetes = datasets.load_diabetes()
X_tr, X_te, y_tr, y_te = model_selection.train_test_split(
    diabetes.data, diabetes.target, test_size=test_size, random_state=random_state)

# %%
print(diabetes.feature_names)
diabetes.data[:,1].min()

plt.plot(diabetes.data[:,0],"ro")
plt.show()
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# <img src="data:image/png;base64,..." width="640">

# %%
model = linear_model.LinearRegression()

model.fit(X_train, y_train)

y_tr_pr = model.predict(X_tr)
y_te_pr = model.predict(X_te)

# %%
# Print Errors

# Training set
print("Training set  : Mean squared error: %.3f" % mean_squared_error(y_tr, y_tr_pr))

# Test set
print("Test set      : Mean squared error: %.3f" % mean_squared_error(y_te, y_te_pr))
# Out:
# Training set  : Mean squared error: 2795.669
# Test set      : Mean squared error: 3166.850

# %%
# Plot
plt.figure()
plt.scatter(np.arange(len(y_te)), y_te,  color='black')
plt.plot(np.arange(len(y_te)), y_te_pr, '-o', color='blue', linewidth=1)
plt.show()

plt.figure()
plt.plot(np.arange(len(y_te)), np.abs(y_te_pr - y_te), '-o', color='blue', linewidth=1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
